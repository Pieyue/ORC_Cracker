# %% [markdown]
# # Import Package

# %%
import os
import tensorflow as tf
import keras.src.legacy.backend
from tensorflow.keras.layers import *
from CaptchaDataset import Dataset

BATCH_SIZE = 512
IMG_HEIGHT = 60
IMG_WIDTH = 160
CHANNEL = 3
CAPTCHA_LENGTH = 4
N_LABELS = 62
ds = Dataset(height=IMG_HEIGHT, width=IMG_WIDTH)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True) # distribute GPU memory dynamic.
        print(f"{len(gpus)} GPU(s) available. Memory growth enabled.")
    except RuntimeError as e:
        print(e)
else:
    print("No GPU detected.")

# %% [markdown]
# # Create Dataset

# %%
# ds.build_dataset()

# %% [markdown]
# # Preprocessing Data

# %%
# Load captcha positions and labels
train_name, train_labels = ds.load_labels('datasets/train/labels.csv')
val_name, val_labels = ds.load_labels('datasets/val/labels.csv')

# Create train dataset
train_dataset = ds.captcha_image_generator('datasets/train', train_name, train_labels)
# batch()：Divide dataset according to batch size；prefetch()：Read data previously
train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)

# Create validation dataset
val_dataset = ds.captcha_image_generator('datasets/val', val_name, val_labels)
val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # Model Define

# %%
def RNN_Model():
    model = keras.Sequential([
        # 第一组卷积
        Conv2D(32, (3, 3), activation='relu', padding='same'), # 每个卷积核生成一张特征图，所以输出通道数为卷积核数量
        BatchNormalization(),
        MaxPooling2D((2, 2)),  # 高度和宽度都减半：60->30, 160->80
        Dropout(0.25),
        
        # 第二组卷积
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),  # 30->15, 80->40
        Dropout(0.25),
        
        # 第三组卷积
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),  # 15->7, 40->20
        Dropout(0.25),
        
        # 第四组卷积 - 将宽度减少到接近4
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((1, 5)),  # 高度不变，宽度：20->4
        Dropout(0.25),
        
        # 当前shape - (None, 7, 4, 128)
        # 将高度和通道展平为特征
        # 每个字符是一个时间步，4个时间步，每个时间步有896个特征
        Reshape((4, 7 * 128)),  # (时间步，特征数)
        
        # LSTM - 一种RNN架构，可以让模型像人一样从左往右看，并记住重要的信息进行判断
        # Bidirectional - 让模型也可以从右往左看
        Bidirectional(LSTM(128, return_sequences=True)),
        BatchNormalization(),
        Dropout(0.3),
        
        # 对每一个时间步输出的字符都运用Dense()
        TimeDistributed(Dense(64, activation='relu')),
        BatchNormalization(),
        Dropout(0.3),
        
        # 输出层 - 每个时间步对应一个字符
        TimeDistributed(Dense(N_LABELS, activation='softmax')),
    ])
    return model

# %%
model = RNN_Model()
model.build(input_shape=[None, IMG_HEIGHT, IMG_WIDTH, CHANNEL]) # 批次大小设置为None模型可以接收批次任意大小的数据
optimizer = keras.optimizers.Adam(
    learning_rate=0.0005,  # RNN通常需要稍大的学习率
    clipnorm=1.0
)


model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_28 (Conv2D)              │ (None, 60, 160, 32)    │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 60, 160, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_28 (MaxPooling2D) │ (None, 30, 80, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 30, 80, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 30, 80, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 30, 80, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_29 (MaxPooling2D) │ (None, 15, 40, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 15, 40, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_30 (Conv2D)              │ (None, 15, 40, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 15, 40, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_30 (MaxPooling2D) │ (None, 7, 20, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_46 (Dropout)            │ (None, 7, 20, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 7, 20, 128)     │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_47          │ (None, 7, 20, 128)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_31 (MaxPooling2D) │ (None, 7, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_47 (Dropout)            │ (None, 7, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_8 (Reshape)             │ (None, 4, 896)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_8 (Bidirectional) │ (None, 4, 256)         │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_48          │ (None, 4, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_48 (Dropout)            │ (None, 4, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_16             │ (None, 4, 64)          │        16,448 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 4, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_49 (Dropout)            │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_17             │ (None, 4, 62)          │         4,030 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,313,598 (5.01 MB)
#  Trainable params: 1,312,254 (5.01 MB)
#  Non-trainable params: 1,344 (5.25 KB)

# %% [markdown]
# # Callbacks

# %%
root = os.getcwd()
ckpt_path = os.path.join(root, 'checkpoints')
if not os.path.exists(ckpt_path):
    os.mkdir(ckpt_path)
weight_file = os.path.join(ckpt_path, 'CNN_RNN_{epoch:04d}.keras')

ck_callbacks = keras.callbacks.ModelCheckpoint(
    filepath=weight_file,
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    verbose = 1
)
tb_callbacks = keras.callbacks.TensorBoard(
    log_dir='./logs',
    histogram_freq=1,
    update_freq=1
)
# 动态调整学习率
lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,     # 降低因子
    patience=5,
    min_lr=1e-7,    # 最小学习率
    verbose=1
)
early_stop = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    min_delta=0.001
)

# %% [markdown]
# # Model Training

# %%
with tf.device('/GPU:0'):
    history = model.fit(x=train_dataset, batch_size=BATCH_SIZE, validation_data=val_dataset, epochs=400, callbacks=[ck_callbacks, tb_callbacks, lr_scheduler, early_stop])
# Out:
# Epoch 1/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.3694 - loss: 2.1619
# Epoch 1: val_accuracy improved from -inf to 0.08341, saving model to /kaggle/working/checkpoints/CNN_RNN_0001.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 90s 571ms/step - accuracy: 0.3696 - loss: 2.1610 - val_accuracy: 0.0834 - val_loss: 5.7672 - learning_rate: 5.0000e-04
# Epoch 2/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.4983 - loss: 1.6853
# Epoch 2: val_accuracy improved from 0.08341 to 0.12061, saving model to /kaggle/working/checkpoints/CNN_RNN_0002.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.4984 - loss: 1.6847 - val_accuracy: 0.1206 - val_loss: 5.7824 - learning_rate: 5.0000e-04
# Epoch 3/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.5879 - loss: 1.3562
# Epoch 3: val_accuracy improved from 0.12061 to 0.12664, saving model to /kaggle/working/checkpoints/CNN_RNN_0003.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 567ms/step - accuracy: 0.5880 - loss: 1.3558 - val_accuracy: 0.1266 - val_loss: 5.7603 - learning_rate: 5.0000e-04
# Epoch 4/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.6553 - loss: 1.1243
# Epoch 4: val_accuracy improved from 0.12664 to 0.20717, saving model to /kaggle/working/checkpoints/CNN_RNN_0004.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.6554 - loss: 1.1241 - val_accuracy: 0.2072 - val_loss: 4.9415 - learning_rate: 5.0000e-04
# Epoch 5/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.7021 - loss: 0.9589
# Epoch 5: val_accuracy improved from 0.20717 to 0.74160, saving model to /kaggle/working/checkpoints/CNN_RNN_0005.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 564ms/step - accuracy: 0.7021 - loss: 0.9587 - val_accuracy: 0.7416 - val_loss: 0.9632 - learning_rate: 5.0000e-04
# Epoch 6/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7387 - loss: 0.8302
# Epoch 6: val_accuracy did not improve from 0.74160
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 569ms/step - accuracy: 0.7387 - loss: 0.8300 - val_accuracy: 0.6534 - val_loss: 1.3369 - learning_rate: 5.0000e-04
# Epoch 7/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7669 - loss: 0.7342
# Epoch 7: val_accuracy improved from 0.74160 to 0.86044, saving model to /kaggle/working/checkpoints/CNN_RNN_0007.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 568ms/step - accuracy: 0.7670 - loss: 0.7341 - val_accuracy: 0.8604 - val_loss: 0.4676 - learning_rate: 5.0000e-04
# Epoch 8/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.7871 - loss: 0.6646
# Epoch 8: val_accuracy did not improve from 0.86044
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.7872 - loss: 0.6645 - val_accuracy: 0.6004 - val_loss: 1.6414 - learning_rate: 5.0000e-04
# Epoch 9/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8053 - loss: 0.6050
# Epoch 9: val_accuracy did not improve from 0.86044
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 567ms/step - accuracy: 0.8053 - loss: 0.6049 - val_accuracy: 0.7599 - val_loss: 0.8862 - learning_rate: 5.0000e-04
# Epoch 10/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8203 - loss: 0.5541
# Epoch 10: val_accuracy did not improve from 0.86044
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 563ms/step - accuracy: 0.8203 - loss: 0.5540 - val_accuracy: 0.5338 - val_loss: 2.4530 - learning_rate: 5.0000e-04
# Epoch 11/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.8320 - loss: 0.5148
# Epoch 11: val_accuracy did not improve from 0.86044
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 564ms/step - accuracy: 0.8320 - loss: 0.5148 - val_accuracy: 0.6424 - val_loss: 1.7083 - learning_rate: 5.0000e-04
# Epoch 12/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8432 - loss: 0.4796
# Epoch 12: val_accuracy improved from 0.86044 to 0.92724, saving model to /kaggle/working/checkpoints/CNN_RNN_0012.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 568ms/step - accuracy: 0.8432 - loss: 0.4796 - val_accuracy: 0.9272 - val_loss: 0.2318 - learning_rate: 5.0000e-04
# Epoch 13/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8517 - loss: 0.4501
# Epoch 13: val_accuracy did not improve from 0.92724
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 567ms/step - accuracy: 0.8517 - loss: 0.4501 - val_accuracy: 0.9190 - val_loss: 0.2628 - learning_rate: 5.0000e-04
# Epoch 14/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.8592 - loss: 0.4264
# Epoch 14: val_accuracy improved from 0.92724 to 0.93584, saving model to /kaggle/working/checkpoints/CNN_RNN_0014.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 564ms/step - accuracy: 0.8592 - loss: 0.4264 - val_accuracy: 0.9358 - val_loss: 0.2010 - learning_rate: 5.0000e-04
# Epoch 15/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.8674 - loss: 0.4006
# Epoch 15: val_accuracy improved from 0.93584 to 0.94514, saving model to /kaggle/working/checkpoints/CNN_RNN_0015.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 560ms/step - accuracy: 0.8674 - loss: 0.4005 - val_accuracy: 0.9451 - val_loss: 0.1716 - learning_rate: 5.0000e-04
# Epoch 16/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8735 - loss: 0.3820
# Epoch 16: val_accuracy did not improve from 0.94514
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 563ms/step - accuracy: 0.8735 - loss: 0.3820 - val_accuracy: 0.8077 - val_loss: 0.7109 - learning_rate: 5.0000e-04
# Epoch 17/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.8781 - loss: 0.3639
# Epoch 17: val_accuracy improved from 0.94514 to 0.94547, saving model to /kaggle/working/checkpoints/CNN_RNN_0017.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.8781 - loss: 0.3639 - val_accuracy: 0.9455 - val_loss: 0.1674 - learning_rate: 5.0000e-04
# Epoch 18/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.8823 - loss: 0.3531
# Epoch 18: val_accuracy did not improve from 0.94547
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 568ms/step - accuracy: 0.8823 - loss: 0.3531 - val_accuracy: 0.6492 - val_loss: 1.7195 - learning_rate: 5.0000e-04
# Epoch 19/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8863 - loss: 0.3398
# Epoch 19: val_accuracy improved from 0.94547 to 0.94759, saving model to /kaggle/working/checkpoints/CNN_RNN_0019.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 564ms/step - accuracy: 0.8863 - loss: 0.3398 - val_accuracy: 0.9476 - val_loss: 0.1750 - learning_rate: 5.0000e-04
# Epoch 20/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.8890 - loss: 0.3307
# Epoch 20: val_accuracy did not improve from 0.94759
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.8891 - loss: 0.3307 - val_accuracy: 0.8777 - val_loss: 0.4443 - learning_rate: 5.0000e-04
# Epoch 21/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.8946 - loss: 0.3123
# Epoch 21: val_accuracy improved from 0.94759 to 0.95500, saving model to /kaggle/working/checkpoints/CNN_RNN_0021.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 90s 570ms/step - accuracy: 0.8946 - loss: 0.3122 - val_accuracy: 0.9550 - val_loss: 0.1320 - learning_rate: 5.0000e-04
# Epoch 22/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.8975 - loss: 0.3027
# Epoch 22: val_accuracy did not improve from 0.95500
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 565ms/step - accuracy: 0.8975 - loss: 0.3027 - val_accuracy: 0.9438 - val_loss: 0.1983 - learning_rate: 5.0000e-04
# Epoch 23/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9008 - loss: 0.2922
# Epoch 23: val_accuracy did not improve from 0.95500
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 568ms/step - accuracy: 0.9008 - loss: 0.2922 - val_accuracy: 0.7099 - val_loss: 1.5046 - learning_rate: 5.0000e-04
# Epoch 24/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.9026 - loss: 0.2854
# Epoch 24: val_accuracy did not improve from 0.95500
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 569ms/step - accuracy: 0.9026 - loss: 0.2854 - val_accuracy: 0.8569 - val_loss: 0.5451 - learning_rate: 5.0000e-04
# Epoch 25/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9057 - loss: 0.2791
# Epoch 25: val_accuracy did not improve from 0.95500
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 564ms/step - accuracy: 0.9057 - loss: 0.2791 - val_accuracy: 0.7480 - val_loss: 1.1385 - learning_rate: 5.0000e-04
# Epoch 26/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9084 - loss: 0.2729
# Epoch 26: val_accuracy did not improve from 0.95500
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 565ms/step - accuracy: 0.9084 - loss: 0.2729 - val_accuracy: 0.9401 - val_loss: 0.1888 - learning_rate: 5.0000e-04
# Epoch 27/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.9132 - loss: 0.2556
# Epoch 27: val_accuracy improved from 0.95500 to 0.96120, saving model to /kaggle/working/checkpoints/CNN_RNN_0027.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 90s 573ms/step - accuracy: 0.9132 - loss: 0.2555 - val_accuracy: 0.9612 - val_loss: 0.1153 - learning_rate: 2.5000e-04
# Epoch 28/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.9155 - loss: 0.2447
# Epoch 28: val_accuracy did not improve from 0.96120
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 90s 571ms/step - accuracy: 0.9156 - loss: 0.2447 - val_accuracy: 0.8079 - val_loss: 0.8283 - learning_rate: 2.5000e-04
# Epoch 29/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9181 - loss: 0.2385
# Epoch 29: val_accuracy improved from 0.96120 to 0.96325, saving model to /kaggle/working/checkpoints/CNN_RNN_0029.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 565ms/step - accuracy: 0.9181 - loss: 0.2385 - val_accuracy: 0.9632 - val_loss: 0.1079 - learning_rate: 2.5000e-04
# Epoch 30/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.9190 - loss: 0.2347
# Epoch 30: val_accuracy did not improve from 0.96325
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 90s 570ms/step - accuracy: 0.9191 - loss: 0.2347 - val_accuracy: 0.9514 - val_loss: 0.1669 - learning_rate: 2.5000e-04
# Epoch 31/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9197 - loss: 0.2332
# Epoch 31: val_accuracy did not improve from 0.96325
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.9197 - loss: 0.2331 - val_accuracy: 0.7586 - val_loss: 1.2639 - learning_rate: 2.5000e-04
# Epoch 32/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.9207 - loss: 0.2280
# Epoch 32: val_accuracy did not improve from 0.96325
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.9207 - loss: 0.2279 - val_accuracy: 0.9569 - val_loss: 0.1429 - learning_rate: 2.5000e-04
# Epoch 33/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9233 - loss: 0.2231
# Epoch 33: val_accuracy improved from 0.96325 to 0.96657, saving model to /kaggle/working/checkpoints/CNN_RNN_0033.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 568ms/step - accuracy: 0.9233 - loss: 0.2231 - val_accuracy: 0.9666 - val_loss: 0.0994 - learning_rate: 2.5000e-04
# Epoch 34/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.9247 - loss: 0.2186
# Epoch 34: val_accuracy did not improve from 0.96657
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 569ms/step - accuracy: 0.9247 - loss: 0.2186 - val_accuracy: 0.8215 - val_loss: 0.8250 - learning_rate: 2.5000e-04
# Epoch 35/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.9253 - loss: 0.2177
# Epoch 35: val_accuracy did not improve from 0.96657
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.9253 - loss: 0.2177 - val_accuracy: 0.9561 - val_loss: 0.1544 - learning_rate: 2.5000e-04
# Epoch 36/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9258 - loss: 0.2141
# Epoch 36: val_accuracy did not improve from 0.96657
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 563ms/step - accuracy: 0.9258 - loss: 0.2141 - val_accuracy: 0.9642 - val_loss: 0.1059 - learning_rate: 2.5000e-04
# Epoch 37/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9269 - loss: 0.2110
# Epoch 37: val_accuracy did not improve from 0.96657
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.9269 - loss: 0.2110 - val_accuracy: 0.9609 - val_loss: 0.1232 - learning_rate: 2.5000e-04
# Epoch 38/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9271 - loss: 0.2113
# Epoch 38: val_accuracy did not improve from 0.96657
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 565ms/step - accuracy: 0.9271 - loss: 0.2113 - val_accuracy: 0.8840 - val_loss: 0.4638 - learning_rate: 2.5000e-04
# Epoch 39/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.9297 - loss: 0.2042
# Epoch 39: val_accuracy improved from 0.96657 to 0.96770, saving model to /kaggle/working/checkpoints/CNN_RNN_0039.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 564ms/step - accuracy: 0.9297 - loss: 0.2042 - val_accuracy: 0.9677 - val_loss: 0.0947 - learning_rate: 1.2500e-04
# Epoch 40/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9310 - loss: 0.1989
# Epoch 40: val_accuracy did not improve from 0.96770
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 565ms/step - accuracy: 0.9310 - loss: 0.1989 - val_accuracy: 0.9655 - val_loss: 0.1088 - learning_rate: 1.2500e-04
# Epoch 41/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.9312 - loss: 0.1966
# Epoch 41: val_accuracy did not improve from 0.96770
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 90s 572ms/step - accuracy: 0.9312 - loss: 0.1966 - val_accuracy: 0.9626 - val_loss: 0.1241 - learning_rate: 1.2500e-04
# Epoch 42/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.9331 - loss: 0.1936
# Epoch 42: val_accuracy improved from 0.96770 to 0.96875, saving model to /kaggle/working/checkpoints/CNN_RNN_0042.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 90s 571ms/step - accuracy: 0.9330 - loss: 0.1936 - val_accuracy: 0.9687 - val_loss: 0.0913 - learning_rate: 1.2500e-04
# Epoch 43/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.9331 - loss: 0.1922
# Epoch 43: val_accuracy did not improve from 0.96875
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 90s 572ms/step - accuracy: 0.9331 - loss: 0.1922 - val_accuracy: 0.9678 - val_loss: 0.0985 - learning_rate: 1.2500e-04
# Epoch 44/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.9328 - loss: 0.1939
# Epoch 44: val_accuracy did not improve from 0.96875
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 90s 572ms/step - accuracy: 0.9328 - loss: 0.1939 - val_accuracy: 0.9634 - val_loss: 0.1178 - learning_rate: 1.2500e-04
# Epoch 45/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9335 - loss: 0.1913
# Epoch 45: val_accuracy improved from 0.96875 to 0.96977, saving model to /kaggle/working/checkpoints/CNN_RNN_0045.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.9335 - loss: 0.1913 - val_accuracy: 0.9698 - val_loss: 0.0909 - learning_rate: 1.2500e-04
# Epoch 46/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9344 - loss: 0.1886
# Epoch 46: val_accuracy did not improve from 0.96977
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 565ms/step - accuracy: 0.9344 - loss: 0.1886 - val_accuracy: 0.9691 - val_loss: 0.0898 - learning_rate: 1.2500e-04
# Epoch 47/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.9346 - loss: 0.1879
# Epoch 47: val_accuracy did not improve from 0.96977
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 569ms/step - accuracy: 0.9346 - loss: 0.1879 - val_accuracy: 0.9666 - val_loss: 0.1080 - learning_rate: 1.2500e-04
# Epoch 48/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.9341 - loss: 0.1881
# Epoch 48: val_accuracy did not improve from 0.96977
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 567ms/step - accuracy: 0.9341 - loss: 0.1881 - val_accuracy: 0.9606 - val_loss: 0.1371 - learning_rate: 1.2500e-04
# Epoch 49/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9356 - loss: 0.1851
# Epoch 49: val_accuracy did not improve from 0.96977
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.9356 - loss: 0.1851 - val_accuracy: 0.9672 - val_loss: 0.1021 - learning_rate: 1.2500e-04
# Epoch 50/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.9368 - loss: 0.1807
# Epoch 50: val_accuracy did not improve from 0.96977
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 561ms/step - accuracy: 0.9368 - loss: 0.1807 - val_accuracy: 0.9698 - val_loss: 0.0878 - learning_rate: 1.2500e-04
# Epoch 51/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.9370 - loss: 0.1790
# Epoch 51: val_accuracy improved from 0.96977 to 0.97042, saving model to /kaggle/working/checkpoints/CNN_RNN_0051.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.9370 - loss: 0.1790 - val_accuracy: 0.9704 - val_loss: 0.0862 - learning_rate: 6.2500e-05
# Epoch 52/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.9371 - loss: 0.1796
# Epoch 52: val_accuracy improved from 0.97042 to 0.97085, saving model to /kaggle/working/checkpoints/CNN_RNN_0052.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 559ms/step - accuracy: 0.9371 - loss: 0.1796 - val_accuracy: 0.9708 - val_loss: 0.0864 - learning_rate: 6.2500e-05
# Epoch 53/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9379 - loss: 0.1784
# Epoch 53: val_accuracy did not improve from 0.97085
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 565ms/step - accuracy: 0.9379 - loss: 0.1784 - val_accuracy: 0.9700 - val_loss: 0.0899 - learning_rate: 6.2500e-05
# Epoch 54/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.9375 - loss: 0.1765
# Epoch 54: val_accuracy did not improve from 0.97085
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 568ms/step - accuracy: 0.9375 - loss: 0.1765 - val_accuracy: 0.9545 - val_loss: 0.1522 - learning_rate: 6.2500e-05
# Epoch 55/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.9386 - loss: 0.1754
# Epoch 55: val_accuracy did not improve from 0.97085
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 567ms/step - accuracy: 0.9386 - loss: 0.1754 - val_accuracy: 0.7912 - val_loss: 1.0928 - learning_rate: 6.2500e-05
# Epoch 56/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.9389 - loss: 0.1742
# Epoch 56: val_accuracy improved from 0.97085 to 0.97167, saving model to /kaggle/working/checkpoints/CNN_RNN_0056.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 563ms/step - accuracy: 0.9389 - loss: 0.1742 - val_accuracy: 0.9717 - val_loss: 0.0834 - learning_rate: 6.2500e-05
# Epoch 57/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.9396 - loss: 0.1730
# Epoch 57: val_accuracy did not improve from 0.97167
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 560ms/step - accuracy: 0.9396 - loss: 0.1730 - val_accuracy: 0.9691 - val_loss: 0.0991 - learning_rate: 6.2500e-05
# Epoch 58/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.9401 - loss: 0.1751
# Epoch 58: val_accuracy did not improve from 0.97167
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.9401 - loss: 0.1751 - val_accuracy: 0.9701 - val_loss: 0.0861 - learning_rate: 6.2500e-05
# Epoch 59/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9394 - loss: 0.1720
# Epoch 59: val_accuracy did not improve from 0.97167
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.9394 - loss: 0.1720 - val_accuracy: 0.9683 - val_loss: 0.1020 - learning_rate: 6.2500e-05
# Epoch 60/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.9391 - loss: 0.1735
# Epoch 60: val_accuracy improved from 0.97167 to 0.97177, saving model to /kaggle/working/checkpoints/CNN_RNN_0060.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.9391 - loss: 0.1735 - val_accuracy: 0.9718 - val_loss: 0.0845 - learning_rate: 6.2500e-05
# Epoch 61/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.9392 - loss: 0.1728
# Epoch 61: val_accuracy improved from 0.97177 to 0.97255, saving model to /kaggle/working/checkpoints/CNN_RNN_0061.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.9392 - loss: 0.1728 - val_accuracy: 0.9725 - val_loss: 0.0805 - learning_rate: 6.2500e-05
# Epoch 62/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9406 - loss: 0.1702
# Epoch 62: val_accuracy did not improve from 0.97255
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 564ms/step - accuracy: 0.9406 - loss: 0.1702 - val_accuracy: 0.8654 - val_loss: 0.5899 - learning_rate: 6.2500e-05
# Epoch 63/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.9402 - loss: 0.1707
# Epoch 63: val_accuracy did not improve from 0.97255
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 561ms/step - accuracy: 0.9402 - loss: 0.1706 - val_accuracy: 0.9512 - val_loss: 0.1735 - learning_rate: 6.2500e-05
# Epoch 64/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.9400 - loss: 0.1723
# Epoch 64: val_accuracy did not improve from 0.97255
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.9400 - loss: 0.1723 - val_accuracy: 0.9714 - val_loss: 0.0826 - learning_rate: 6.2500e-05
# Epoch 65/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.9398 - loss: 0.1718
# Epoch 65: val_accuracy did not improve from 0.97255
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 563ms/step - accuracy: 0.9398 - loss: 0.1718 - val_accuracy: 0.9717 - val_loss: 0.0827 - learning_rate: 6.2500e-05
# Epoch 66/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.9397 - loss: 0.1705
# Epoch 66: val_accuracy did not improve from 0.97255
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 561ms/step - accuracy: 0.9397 - loss: 0.1705 - val_accuracy: 0.9717 - val_loss: 0.0847 - learning_rate: 6.2500e-05
# Epoch 67/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9412 - loss: 0.1670
# Epoch 67: val_accuracy did not improve from 0.97255
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 563ms/step - accuracy: 0.9412 - loss: 0.1670 - val_accuracy: 0.9717 - val_loss: 0.0815 - learning_rate: 3.1250e-05
# Epoch 68/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.9419 - loss: 0.1647
# Epoch 68: val_accuracy did not improve from 0.97255
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 561ms/step - accuracy: 0.9419 - loss: 0.1647 - val_accuracy: 0.9716 - val_loss: 0.0805 - learning_rate: 3.1250e-05
# Epoch 69/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9414 - loss: 0.1660
# Epoch 69: val_accuracy did not improve from 0.97255
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 89s 564ms/step - accuracy: 0.9414 - loss: 0.1660 - val_accuracy: 0.9716 - val_loss: 0.0840 - learning_rate: 3.1250e-05
# Epoch 70/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.9412 - loss: 0.1675
# Epoch 70: val_accuracy did not improve from 0.97255
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 563ms/step - accuracy: 0.9412 - loss: 0.1675 - val_accuracy: 0.9721 - val_loss: 0.0801 - learning_rate: 3.1250e-05
# Epoch 71/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.9414 - loss: 0.1671
# Epoch 71: val_accuracy did not improve from 0.97255
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.9414 - loss: 0.1671 - val_accuracy: 0.9724 - val_loss: 0.0815 - learning_rate: 3.1250e-05
# Epoch 72/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.9419 - loss: 0.1646
# Epoch 72: val_accuracy did not improve from 0.97255
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 561ms/step - accuracy: 0.9419 - loss: 0.1646 - val_accuracy: 0.9718 - val_loss: 0.0803 - learning_rate: 1.5625e-05
# Epoch 73/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.9416 - loss: 0.1658
# Epoch 73: val_accuracy improved from 0.97255 to 0.97265, saving model to /kaggle/working/checkpoints/CNN_RNN_0073.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.9416 - loss: 0.1658 - val_accuracy: 0.9726 - val_loss: 0.0799 - learning_rate: 1.5625e-05
# Epoch 74/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.9432 - loss: 0.1629
# Epoch 74: val_accuracy did not improve from 0.97265
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 560ms/step - accuracy: 0.9432 - loss: 0.1629 - val_accuracy: 0.9714 - val_loss: 0.0843 - learning_rate: 1.5625e-05
# Epoch 75/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.9422 - loss: 0.1633
# Epoch 75: val_accuracy did not improve from 0.97265
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 563ms/step - accuracy: 0.9422 - loss: 0.1633 - val_accuracy: 0.9723 - val_loss: 0.0817 - learning_rate: 1.5625e-05
# Epoch 76/400
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.9430 - loss: 0.1627
# Epoch 76: val_accuracy did not improve from 0.97265
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 88s 560ms/step - accuracy: 0.9430 - loss: 0.1627 - val_accuracy: 0.9723 - val_loss: 0.0804 - learning_rate: 1.5625e-05
